# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/home/craig/Documents/python_finance/UdemyPortilla/Python-Finance-QuantConnect/03-Core-Pandas/tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
#Really should use this to replace a single value (like an error)
df['sex'].replace(['Female', 'Male'], ['F', 'M'])
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %%
#map functionality
mymap = {'Female':'F', 'Male':'M'}

# %%
df['sex'] = df['sex'].map(mymap)

# %%
df
# Out:
#      total_bill   tip sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01   F     No   Sun  Dinner     2              8.49
# 1         10.34  1.66   M     No   Sun  Dinner     3              3.45
# 2         21.01  3.50   M     No   Sun  Dinner     3              7.00
# 3         23.68  3.31   M     No   Sun  Dinner     2             11.84
# 4         24.59  3.61   F     No   Sun  Dinner     4              6.15
# ..          ...   ...  ..    ...   ...     ...   ...               ...
# 239       29.03  5.92   M     No   Sat  Dinner     3              9.68
# 240       27.18  2.00   F    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00   M    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75   M     No   Sat  Dinner     2              8.91
# 243       18.78  3.00   F     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# ...

# %%
#take a sample of rows
df.sample(10)
# Out:
#      total_bill   tip sex smoker   day    time  size  price_per_person  \
# 83        32.68  5.00   M    Yes  Thur   Lunch     2             16.34
# 141       34.30  6.70   M     No  Thur   Lunch     6              5.72
# 224       13.42  1.58   M    Yes   Fri   Lunch     2              6.71
# 54        25.56  4.34   M     No   Sun  Dinner     4              6.39
# 101       15.38  3.00   F    Yes   Fri  Dinner     2              7.69
# 233       10.77  1.47   M     No   Sat  Dinner     2              5.38
# 174       16.82  4.00   M    Yes   Sun  Dinner     2              8.41
# 231       15.69  3.00   M    Yes   Sat  Dinner     3              5.23
# 150       14.07  2.50   M     No   Sun  Dinner     2              7.04
# 85        34.83  5.17   F     No  Thur   Lunch     4              8.71
#
#             Payer Name         CC Number Payment ID
# 83       Daniel Murphy  5356177501009133   Thur8801
# 141     Steven Carlson  3526515703718508   Thur1025
# ...

# %%
#take a sample of rows based on percent of df---10% here
df.sample(frac=0.10)
# Out:
#      total_bill   tip sex smoker   day    time  size  price_per_person  \
# 142       41.19  5.00   M     No  Thur   Lunch     5              8.24
# 197       43.11  5.00   F    Yes  Thur   Lunch     4             10.78
# 239       29.03  5.92   M     No   Sat  Dinner     3              9.68
# 198       13.00  2.00   F    Yes  Thur   Lunch     2              6.50
# 184       40.55  3.00   M    Yes   Sun  Dinner     2             20.27
# 75        10.51  1.25   M     No   Sat  Dinner     2              5.26
# 17        16.29  3.71   M     No   Sun  Dinner     3              5.43
# 32        15.06  3.00   F     No   Sat  Dinner     2              7.53
# 140       17.47  3.50   F     No  Thur   Lunch     2              8.74
# 104       20.92  4.08   F     No   Sat  Dinner     2             10.46
# 164       17.51  3.00   F    Yes   Sun  Dinner     2              8.76
# 222        8.58  1.92   M    Yes   Fri   Lunch     1              8.58
# ...
