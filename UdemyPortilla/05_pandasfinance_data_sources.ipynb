# %%
import pandas_datareader as pdr
import pandas as pd
import datetime as dt
import yfinance as yf

# %%
start = dt.datetime(2021, 1, 1)
end = dt.datetime(2022, 2, 14)
ticker = 'AAPL'
av_key = 'GNMEXKEV18198WV5'

# %%
yahoo_df = pdr.get_data_yahoo(ticker, start, end)
yahoo_df
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2021-01-04  133.610001  126.760002  133.520004  129.410004  143301900.0
# 2021-01-05  131.740005  128.429993  128.889999  131.009995   97664900.0
# 2021-01-06  131.050003  126.379997  127.720001  126.599998  155088000.0
# 2021-01-07  131.630005  127.860001  128.360001  130.919998  109578200.0
# 2021-01-08  132.630005  130.229996  132.429993  132.050003  105158200.0
# ...                ...         ...         ...         ...          ...
# 2022-02-08  175.350006  171.429993  171.729996  174.830002   74829200.0
# 2022-02-09  176.649994  174.899994  176.050003  176.279999   71285000.0
# 2022-02-10  175.479996  171.550003  174.139999  172.119995   90865900.0
# 2022-02-11  173.080002  168.039993  172.330002  168.639999   98566000.0
# 2022-02-14  169.580002  166.559998  167.369995  168.880005   86185500.0
#
#              Adj Close
# Date
# 2021-01-04  128.453445
# 2021-01-05  130.041611
# ...

# %%
#you can use this function for all calls just need to specifiy yahoo, av-dailys, fred, etc.
alpha_vantage_df = pdr.DataReader("AAPL", "av-daily", start, end, api_key=av_key)
alpha_vantage_df
# Out:
#               open      high      low   close     volume
# 2021-01-04  133.52  133.6116  126.760  129.41  143301887
# 2021-01-05  128.89  131.7400  128.430  131.01   97664898
# 2021-01-06  127.72  131.0499  126.382  126.60  155087970
# 2021-01-07  128.36  131.6300  127.860  130.92  109578157
# 2021-01-08  132.43  132.6300  130.230  132.05  105158245
# ...            ...       ...      ...     ...        ...
# 2022-02-08  171.73  175.3500  171.430  174.83   74829217
# 2022-02-09  176.05  176.6500  174.900  176.28   71285038
# 2022-02-10  174.14  175.4800  171.550  172.12   90865899
# 2022-02-11  172.33  173.0800  168.040  168.64   98670687
# 2022-02-14  167.37  169.5800  166.560  168.88   86185530
#
# [282 rows x 5 columns]

# %%
fred_df = pdr.DataReader("GDP", "fred", start, end)
fred_df
# Out:
#                   GDP
# DATE
# 2021-01-01  22038.226
# 2021-04-01  22740.959
# 2021-07-01  23202.344
# 2021-10-01  24008.472

# %%
# yf allows you to download a ton of info (IS, BS, rev, etc. )
#can do regular daily stock prices 
apple = yf.download('AAPL', start='2020-01-01', end='2021-01-01')
apple
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02   74.059998   75.150002   73.797501   75.087502   73.894318
# 2020-01-03   74.287498   75.144997   74.125000   74.357498   73.175926
# 2020-01-06   73.447502   74.989998   73.187500   74.949997   73.758995
# 2020-01-07   74.959999   75.224998   74.370003   74.597504   73.412109
# 2020-01-08   74.290001   76.110001   74.290001   75.797501   74.593040
# ...                ...         ...         ...         ...         ...
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  130.994537
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  135.679657
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  133.873077
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  132.731598
# 2020-12-31  134.080002  134.740005  131.720001  132.690002  131.709213
#
#                Volume
# Date
# ...

# %%
#but you can also get detailed financials
apple_ticker = yf.Ticker('AAPL')

# %%
#then do apple_ticker. (tab) to get options
apple_ticker.get_balance_sheet()
# Out:
#                              2021-09-25    2020-09-26    2019-09-28  \
# Total Liab                 2.879120e+11  2.585490e+11  2.480280e+11
# Total Stockholder Equity   6.309000e+10  6.533900e+10  9.048800e+10
# Other Current Liab         5.357700e+10  4.786700e+10  4.324200e+10
# Total Assets               3.510020e+11  3.238880e+11  3.385160e+11
# Common Stock               5.736500e+10  5.077900e+10  4.517400e+10
# Other Current Assets       1.411100e+10  1.126400e+10  1.235200e+10
# Retained Earnings          5.562000e+09  1.496600e+10  4.589800e+10
# Other Liab                 4.305000e+10  4.610800e+10  5.050300e+10
# Treasury Stock             1.630000e+08 -4.060000e+08 -5.840000e+08
# Other Assets               3.876200e+10  3.395200e+10  3.297800e+10
# Cash                       3.494000e+10  3.801600e+10  4.884400e+10
# Total Current Liabilities  1.254810e+11  1.053920e+11  1.057180e+11
# Short Long Term Debt       9.613000e+09  8.773000e+09  1.026000e+10
# ...

# %%
apple_ticker.analysis
# Out:
#         Max Age   End Date   Growth  Earnings Estimate Avg  \
# Period
# 0Q            1 2022-03-31  0.02100                   1.43
# +1Q           1 2022-06-30 -0.04600                   1.24
# 0Y            1 2022-09-30  0.09800                   6.16
# +1Y           1 2023-09-30  0.06500                   6.56
# +5Y           1        NaT  0.14850                    NaN
# -5Y           1        NaT  0.08415                    NaN
#
#         Earnings Estimate Low  Earnings Estimate High  \
# Period
# 0Q                       1.34                    1.56
# +1Q                      1.11                    1.40
# 0Y                       5.83                    6.61
# +1Y                      5.96                    7.30
# +5Y                       NaN                     NaN
# -5Y                       NaN                     NaN
#
#         Earnings Estimate Year Ago Eps  Earnings Estimate Number Of Analysts  \
# Period
# ...
