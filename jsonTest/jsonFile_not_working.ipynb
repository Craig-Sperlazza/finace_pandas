# %%
import pandas as pd

# %%
import os
print(os.getcwd())
# Out:
# /home/craig/Documents/python_finance/jsonTest

# %%
df = pd.read_json('/home/craig/Documents/python_finance/jsonTest/stock.json')

# %%
df2 = pd.read_json('/home/craig/Documents/python_finance/jsonTest/stock.json', encoding="utf8", orient='index')

# %%
df.T
# Out:
#                                           symbol  \
# copyright    Copyright (c) 2010 QuoteMedia, Inc.
# symbolcount                                    2
# quotedata                                     GE
# symbol                                      MSFT
# datatype                                  equity
# entitlement                                   DL
# delaymin                                      15
# datetime               2010-06-08 15:03:40-04:00
# exchange                                     NGS
# longname                         Microsoft Corp.
# shortname                                   MSFT
# pricedata                                    NaN
#
#                                         datatype  \
# copyright    Copyright (c) 2010 QuoteMedia, Inc.
# symbolcount                                    2
# quotedata                                 equity
# symbol                                      MSFT
# datatype                                  equity
# ...

# %%
df2
# Out:
#                                                              0
# copyright                  Copyright (c) 2010 QuoteMedia, Inc.
# symbolcount                                                  2
# quotedata    {'symbol': 'GE', 'datatype': 'equity', 'entitl...
# symbol                                                    MSFT
# datatype                                                equity
# entitlement                                                 DL
# delaymin                                                    15
# datetime                             2010-06-08T15:03:40-04:00
# exchange                                                   NGS
# longname                                       Microsoft Corp.
# shortname                                                 MSFT
# pricedata    {'last': 24.95, 'change': -0.34, 'changepercen...

# %%
df3 = df2.iloc[-1]

# %%
df3.T
# Out:
# 0    {'last': 24.95, 'change': -0.34, 'changepercen...
# Name: pricedata, dtype: object

# %%
df3
# Out:
# 0    {'last': 24.95, 'change': -0.34, 'changepercen...
# Name: pricedata, dtype: object
