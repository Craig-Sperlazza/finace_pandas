# %%
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib notebook

# %%
data = pd.read_csv("./data/NFLX.csv", index_col=0, parse_dates=True)

# %%
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-02-11  564.440002  565.929993  554.219971  557.590027  557.590027
# 2021-02-12  556.940002  561.250000  550.849976  556.520020  556.520020
# 2021-02-16  557.289978  563.630005  552.729980  557.280029  557.280029
# 2021-02-17  550.989990  555.250000  543.030029  551.340027  551.340027
# 2021-02-18  549.000000  550.000000  538.229980  548.219971  548.219971
#
#              Volume
# Date
# 2021-02-11  2730600
# 2021-02-12  2197100
# 2021-02-16  2624100
# 2021-02-17  2069600
# 2021-02-18  2456200

# %%
#note that volume is in miliions o nothing else shows up....this is a bad way to do it obviously
data.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Date'>

# %%
fig, ax = plt.subplots()
data['Close'].plot(ax=ax)
ax.set_ylabel("Price")
ax.set_title("Netflix Close")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Netflix Close')

# %%
#if you look at help, rows, cols are default of 1 (so you get one graph like above)
#set it at 2 and 2 gives you 4 graphs
fix, ax = plt.subplots(2, 2)
# ax is an array of an array so you access sub array
data['Open'].plot(ax=ax[0, 0], title="Open")
data['High'].plot(ax=ax[0, 1], title="High")
data['Low'].plot(ax=ax[1, 0], title="Low")
data['Close'].plot(ax=ax[1, 1], title="Close")

#spaces the graphs out
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fix, ax = plt.subplots()
# Limit time to summer of 2021
#choose column and then rows
data['Volume'].loc['2021-06-01':'2021-08-15'].plot.bar(ax=ax, title="Volume")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:title={'center':'Volume'}, xlabel='Date'>
